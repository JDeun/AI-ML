# %% [markdown]
# # 회귀(Regression)

# %% [markdown]
# 이 노트북에서 우리는 몇 가지 일반적인 회귀 알고리즘에 대하여 논의할 것입니다. 회귀 분석을 살펴봅니다.
#
# ### 회귀 분석이란 무엇입니까? 회귀 분석을 하는 이유는 무엇입니까?
# 회귀 분석은 종속 변수와 독립 변수 간의 관계를 조사합니다. 일반적으로 예측, 시계열 모델링 및 변수 간의 인과 관계를 찾을 때 사용됩니다.
#
#
# 예를 들어 다음 분기의 수확량을 예측하려는 농부가 있다고 가정해 보겠습니다. 강우량, 종자 품질, 토양 품질과 같이 작물 수확량에 영향을 미치는 변수가 많다는 것을 알 수 있습니다. 그 중에 어떤 변수가 작물 수확량에 가장 큰 영향을 미치는지 생각해볼 수 있습니다.
#
# "토양의 질이 높을수록 농작물 수확량이 증가할 수 있습니다." "구름의 양이 많아질 수록 농작물 수확량이 증가할 수도 있습니다."
#
# 이제 모든 변수가 유효하다고 생각할 수도 있습니다! 유효한 관계를 어떠한 방법으로 증명할 수 있을까요?
#
# 회귀 분석을 사용할 수 있습니다. 이를 통해 변수 중 어떤 것이 작물 수확량에 영향을 미칠 수 있는지 수학적으로 결정할 수 있으므로 농부는 정보에 기반하여 전략적인 선택을 취할 수 있습니다. 예를 들어, 토양 품질이 작물에 가장 큰 영향을 미친다는 사실을 아는 것은 농부들이 농장에서 양질의 토양을 유지하기 위해 더 많은 자원을 투입하도록 동기를 부여할 것입니다. 회귀 분석은 가장 중요한 변수, 무시할 수 있는 변수 및 변수가 서로 상호 작용하는 방식을 파악하는데 도움이 됩니다.
#
#
# ### 상관 관계 vs 인과 관계
# 회귀 분석을 할 때 사람들이 가장 많이 법하는 실수 중 하나는 상관 관계를 찾아내고 인과 관계를 가정하는 것입니다. 예제를 살펴보겠습니다. 아래 그래프는 아이스크림을 먹는 사람들의 수가 상어 공격의 수와 상관관계가 있음을 보여줍니다. 이 상관관계를 어떻게 설명하시겠습니까? 아이스크림을 먹으면 상어 공격이 일어난다고 할까요, 아니면 상어의 공격이 더 많은 사람들이 아이스크림을 먹는 결과를 초래한다고 할까요?

# %% [markdown]
# ![Image](resources/icecreamand-sharks.png)

# %% [markdown]
# 사실 아이스크림 판매량과 상어의 공격은 인과관계가 없습니다. 사람들이 아이스크림을 먹는 것은 상어의 공격 횟수에 영향을 미치지 않습니다!
#
# 따라서 데이터를 처리하고 회귀 분석을 수행할 때 반드시 변수 간의 상관 관계가 인과 관계를 의미하는 것은 아니라는 점을 고려해야 합니다.
#
# 즉, 두 변수가 관계가 있다고 해서 한 변수가 다른 변수에 영향을 미친다는 의미는 아닙니다. 두 사건 사이의 관계를 결정하기 전에 검토해야 할 변수가 많이 있습니다. 상관 관계를 일으키는 다른 변수를 찾을 수 있습니다.
#
# 궁금한 사람들을 위해 해당 그래프는 https://www.tylervigen.com/spurious-correlations 에서 가져왔습니다. 해당 링크로 이동하여 흥미로운 상관 관계를 볼 수 있습니다.
#
# 이제 가장 간단한 회귀 분석인 선형 회귀에 대해 알아보겠습니다.

# %% [markdown]
# # 선형 회귀(Linear Regression)

# %% [markdown]
# 선형 회귀는 가장 일반적인 회귀 기법 중 하나입니다. 직선을 사용하여 변수 간의 관계를 나타냅니다. 직선으로 표현할 수 있는 관계는 무엇이 있을까요? 키 대 나이? 공부한 시간과 결과? 더 많이 있습니다!
#
# ### 회귀선
# 최적 적합선으로 알려진 회귀선은 선형 관계를 결정하는 데 사용됩니다. 우리가 비교하는 변수 간의 관계를 가장 잘 나타내는 선입니다.

# %% [markdown]
# 아래 그림을 표시된 직선을 y = mx + c의 방정식으로 설명할 수 있습니다:
# - m은 선의 기울기이고,
# - c는 아래와 같이 y절편(선이 y축/수직선을 절단하는 위치)입니다.

# %% [markdown]
# ![image.png](resources/concepts12.jpeg)

# %% [markdown]
# 회귀 분석을 지원하기 위해 sklearn 라이브러리에는 LinearRegression()이라는 함수가 있습니다. 이 함수는 데이터를 사용하여 최적선이라고도 하는 선형 회귀선을 표시하거나 찾습니다.
#
# 선형 회귀는 최소 제곱법을 사용하여 최적의 선을 구합니다. 이는 y = mx + c의 방정식에서 m과 c를 구하는 것을 의미합니다. 이 경우 실제 값과 예측 값의 간의 차이에 대한 제곱의 최소 합을 구합니다.
#
# 최소 제곱법을 사용하여 선형 회귀를 계산하는 방법에 대해 자세히 알아보려면 이 비디오를 참조하세요. https://www.youtube.com/watch?v=JvS2triCgOY

# %% [markdown]
# # 회귀 문제를 해결하기 위한 단계별 접근

# %% [markdown]
# 우리는 다음 사항을 알고 있습니다:
# - 변수를 산점도에 그려서 변수 간의 관계를 알 수 있습니다.
# - 선을 사용하여 그들 사이의 관계를 나타낼 수 있습니다.
# - 선형 회귀에서 변수 간의 관계를 나타내기 위해 직선을 사용합니다.
# - 최적선은 변수 간의 선형관계를 나타내는 최적선으로 간주됩니다.
#
# 그러면 회귀 분석을 어떻게 수행할 수 있습니까? 데이터 세트를 보고 가장 적합한 선을 적용하려면 어떻게 해야 할까요?
# 회귀 분석의 작동 원리를 단계별로 살펴보겠습니다!
#
# ### 활동 1: 라이브러리 가져오기
#
# 먼저 pandas, matplotlib, numpy 및 seaborn 라이브러리를 가져오겠습니다.
# - pandas와 numpy는 데이터를 구성하고 조작하는 데 도움이 됩니다.
# - matplotlib 및 seaborn은 데이터를 그래프 형태로 시각화하는 데 도움을 줍니다.

# %%
# 라이브러리 가져오기
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %% [markdown]
# ### 활동 2: csv 데이터 읽기
#
# 다음으로 weatherHistory 파일에서 csv 데이터를 읽고 각 특성(features)의 데이터 유형을 살펴보겠습니다. 데이터 사이즈가 클 수 있습니다. head()를 사용하여 처음 10개 값을 출력하십시오.

# %%
# CSV 파일 읽기
data = pd.read_csv("./[Dataset] Module 18 (weatherHistory).csv")

# 처음 10개 값 출력
print(data.head(10))
data.head()
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
# 5  2006-04-01 05:00:00.000 +0200  Partly Cloudy        rain         9.222222
# 6  2006-04-01 06:00:00.000 +0200  Partly Cloudy        rain         7.733333
# 7  2006-04-01 07:00:00.000 +0200  Partly Cloudy        rain         8.772222
# 8  2006-04-01 08:00:00.000 +0200  Partly Cloudy        rain        10.822222
# 9  2006-04-01 09:00:00.000 +0200  Partly Cloudy        rain        13.772222
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# ...

# %% [markdown]
# ### 활동 3:
# 이제 csv 데이터를 읽어왔습니다. 데이터를 보고 다음 질문에 답하십시오.
# 1. 데이터세트에서 사용할 수 있는 기능은 무엇입니까?
# 2. 어떤 종류의 데이터 유형이 있습니까?

# %%
# 특성 데이터 타입 출력
print(data.dtypes)
print(data.info())
# Out:
# Formatted Date               object
# Summary                      object
# Precip Type                  object
# Temperature (C)             float64
# Apparent Temperature (C)    float64
# Humidity                    float64
# Wind Speed (km/h)           float64
# Wind Bearing (degrees)      float64
# Visibility (km)             float64
# Loud Cover                  float64
# Pressure (millibars)        float64
# Daily Summary                object
# dtype: object
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96453 entries, 0 to 96452
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Formatted Date            96453 non-null  object
#  1   Summary                   96453 non-null  object
#  2   Precip Type               95936 non-null  object
#  3   Temperature (C)           96453 non-null  float64
#  4   Apparent Temperature (C)  96453 non-null  float64
# ...

# %% [markdown]
# 위의 데이터 유형을 확인해 보십시오. 어떤 변수가 서로 상관관계가 있다고 생각하십니까? 그 이유는?

# %% [markdown]
# ### 활동 4:
# 어떤 종류의 데이터가 존재하는지 알았으므로 그래프를 그려서 여러 변수들 간의 잠재적인 관계를 살펴보겠습니다! 우선 다음 3가지 관계를 표시해 보겠습니다.
#
# 1. 압력 대 시간
# 2. 습도 대 시간
# 3. 온도 대 시간

# %% [markdown]
# 그래프를 그리기 전에 먼저 0과 NaN 값 데이터를 정리합니다.

# %%
# 0인 요소를 NaN(결측치)로 처리 
data= data.replace(0,np.nan)

# %%
pressure = data['Pressure (millibars)']
humidity = data['Humidity']
temperature = data['Temperature (C)']
#wind_speed = data['Wind Speed (km/h)']
#visibility = data['Visibility (km)']

plt.figure(figsize=(5,5))
ax = sns.scatterplot(x=temperature, y=humidity)
plt.show()

# %% [markdown]
# 점들이 너무 많이 있습니다!
#
# 두 변수 사이의 관계를 나타내는 선을 그릴 수 있다고 생각하십니까?

# %% [markdown]
# 이제 여러분의 차례입니다. 다음 변수들 간의 산점도를 그려 보세요:
# - 압력 대 습도
# - 압력 대 온도

# %% [markdown]
# ### Pressure vs Humidity

# %%
# 압력 대 습도
pressure = data['Pressure (millibars)']
humidity = data['Humidity']
#temperature = data['Temperature (C)']
#wind_speed = data['Wind Speed (km/h)']
#visibility = data['Visibility (km)']

plt.figure(figsize=(5,5))
ax = sns.scatterplot(y=pressure, x=humidity)
plt.show()

# %% [markdown]
# ### Pressure vs Temperature

# %%
# 압력 대 온도
pressure = data['Pressure (millibars)']
#humidity = data['Humidity']
temperature = data['Temperature (C)']
#wind_speed = data['Wind Speed (km/h)']
#visibility = data['Visibility (km)']

plt.figure(figsize=(5,5))
ax3 = sns.scatterplot(y=pressure, x=temperature)
plt.show()

# %% [markdown]
# ### 활동 5:
# 그래프는 변수에 대해 무엇을 알려줍니까?

# %%
# 변수에 대해 많은 관계를 이야기할 수는 없습니다. 변수에 대해 상관 관계를 찾기 어렵다.

# %% [markdown]
# 이제 다른 도구를 사용하여 변수 간의 상관 관계를 시각화할 것입니다.
#
# 상관 맵은 서로 다른 변수를 비교하고 이들 간의 상관 요인을 보여줍니다. 이제 하나를 그려봅시다!

# %%
import seaborn as sns

# %z: 시간대 (UTC+2시간, +0200)
data['Formatted Date'] = pd.to_datetime(data['Formatted Date'], format='%Y-%m-%d %H:%M:%S.%f %z' ,utc=True)

# 텍스트를 Float로 바꿀 수 없으므로 텍스트 필드는 모두 삭제 
data.drop(columns=['Summary'], inplace=True)
data.drop(columns=['Precip Type'], inplace=True)
data.drop(columns=['Daily Summary'], inplace=True)

snsplot = sns.heatmap(data.corr(), annot=True,linewidths=0.5, fmt='.1f')
#snsplot.figure.savefig("corr_data.png")

plt.show()
# Out:
# C:\Users\gadi2\AppData\Local\Temp\ipykernel_13600\4249848786.py:11: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   snsplot = sns.heatmap(data.corr(), annot=True,linewidths=0.5, fmt='.1f')
# c:\Users\gadi2\anaconda3\Lib\site-packages\seaborn\matrix.py:260: FutureWarning: Format strings passed to MaskedConstant are ignored, but in future may error or produce different behavior
#   annotation = ("{:" + self.fmt + "}").format(val)

# %%
import datetime
# 날짜 열을 변환하기 위한 호출
data['Formatted Date'] =  pd.to_datetime(data['Formatted Date'], format='%Y-%m-%d %H:%M:%S.%f', utc=True)
data = data.drop("Loud Cover", axis = 1)

data = data.dropna()
# 날짜 열이 날짜, 시간 형식인지 확인
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 92339 entries, 0 to 96452
# Data columns (total 8 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Formatted Date            92339 non-null  datetime64[ns, UTC]
#  1   Temperature (C)           92339 non-null  float64
#  2   Apparent Temperature (C)  92339 non-null  float64
#  3   Humidity                  92339 non-null  float64
#  4   Wind Speed (km/h)         92339 non-null  float64
#  5   Wind Bearing (degrees)    92339 non-null  float64
#  6   Visibility (km)           92339 non-null  float64
#  7   Pressure (millibars)      92339 non-null  float64
# dtypes: datetime64[ns, UTC](1), float64(7)
# memory usage: 6.3 MB
# None

# %% [markdown]
# data.corr()은 열의 쌍별 상관 관계를 계산하여 상관 계수를 제공합니다. 1 또는 -1에 가까울수록 두 변수의 상관 관계가 높아집니다.

# %% [markdown]
# ### 활동 6
# 어떤 변수가 서로 더 상관관계가 있습니까?

# %%
# 여기에 답을 입력하세요

# %%
import datetime
# 날짜 열을 변환하기 위한 호출
data['Formatted Date'] =  pd.to_datetime(data['Formatted Date'],
                              format='%Y-%m-%d %H:%M:%S.%f', utc=True)
#data = data.drop("Loud Cover", axis = 1)

data = data.dropna()
# 날짜 열이 날짜, 시간 형식인지 확인
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 92339 entries, 0 to 96452
# Data columns (total 8 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Formatted Date            92339 non-null  datetime64[ns, UTC]
#  1   Temperature (C)           92339 non-null  float64
#  2   Apparent Temperature (C)  92339 non-null  float64
#  3   Humidity                  92339 non-null  float64
#  4   Wind Speed (km/h)         92339 non-null  float64
#  5   Wind Bearing (degrees)    92339 non-null  float64
#  6   Visibility (km)           92339 non-null  float64
#  7   Pressure (millibars)      92339 non-null  float64
# dtypes: datetime64[ns, UTC](1), float64(7)
# memory usage: 6.3 MB
# None

# %%
print(data['Formatted Date'][10].month)
# Out:
# 4

# %%
print(data['Formatted Date'][0].day)
print(data['Formatted Date'][0].month)
print(data['Formatted Date'][0].year)
# Out:
# 31
# 3
# 2006

# %%
data['month'] = data['Formatted Date'].dt.month

# %%
data.head()
# Out:
#              Formatted Date  Temperature (C)  Apparent Temperature (C)  \
# 0 2006-03-31 22:00:00+00:00         9.472222                  7.388889
# 1 2006-03-31 23:00:00+00:00         9.355556                  7.227778
# 2 2006-04-01 00:00:00+00:00         9.377778                  9.377778
# 3 2006-04-01 01:00:00+00:00         8.288889                  5.944444
# 4 2006-04-01 02:00:00+00:00         8.755556                  6.977778
#
#    Humidity  Wind Speed (km/h)  Wind Bearing (degrees)  Visibility (km)  \
# 0      0.89            14.1197                   251.0          15.8263
# 1      0.86            14.2646                   259.0          15.8263
# 2      0.89             3.9284                   204.0          14.9569
# 3      0.83            14.1036                   269.0          15.8263
# 4      0.83            11.0446                   259.0          15.8263
#
#    Pressure (millibars)  month
# 0               1015.13      3
# 1               1015.63      3
# ...

# %%
data_jan = data[data.month == 1]
data_feb = data[data.month == 2]
data_mar = data[data.month == 3]
data_apr = data[data.month == 4]
data_may = data[data.month == 5]
data_jun = data[data.month == 6]
data_jul = data[data.month == 7]
data_aug = data[data.month == 8]
data_sep = data[data.month == 9]
data_oct = data[data.month == 10]
data_nov = data[data.month == 11]
data_dec = data[data.month == 12]

# %% [markdown]
# ## 데이터 분석을 위해 1월 데이터 사용

# %%
snsplot = sns.heatmap(data_jan.corr(), annot=True,linewidths=0.5, fmt='.1f')
#snsplot.figure.savefig("corr_data.png")

plt.show()
# Out:
# C:\Users\gadi2\AppData\Local\Temp\ipykernel_13600\1129737697.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   snsplot = sns.heatmap(data_jan.corr(), annot=True,linewidths=0.5, fmt='.1f')
# c:\Users\gadi2\anaconda3\Lib\site-packages\seaborn\matrix.py:260: FutureWarning: Format strings passed to MaskedConstant are ignored, but in future may error or produce different behavior
#   annotation = ("{:" + self.fmt + "}").format(val)

# %% [markdown]
# ## 데이터 분석을 위해 2월 데이터 사용

# %%
snsplot = sns.heatmap(data_feb.corr(), annot=True,linewidths=0.5, fmt='.1f')
#snsplot.figure.savefig("corr_data.png")

plt.show()
# Out:
# C:\Users\gadi2\AppData\Local\Temp\ipykernel_13600\1250600177.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   snsplot = sns.heatmap(data_feb.corr(), annot=True,linewidths=0.5, fmt='.1f')
# c:\Users\gadi2\anaconda3\Lib\site-packages\seaborn\matrix.py:260: FutureWarning: Format strings passed to MaskedConstant are ignored, but in future may error or produce different behavior
#   annotation = ("{:" + self.fmt + "}").format(val)

# %% [markdown]
# ## 데이터 분석을 위해 3월 데이터 사용

# %%
snsplot = sns.heatmap(data_mar.corr(), annot=True,linewidths=0.5, fmt='.1f')
#snsplot.figure.savefig("corr_data.png")

plt.show()
# Out:
# C:\Users\gadi2\AppData\Local\Temp\ipykernel_13600\1440342112.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   snsplot = sns.heatmap(data_mar.corr(), annot=True,linewidths=0.5, fmt='.1f')
# c:\Users\gadi2\anaconda3\Lib\site-packages\seaborn\matrix.py:260: FutureWarning: Format strings passed to MaskedConstant are ignored, but in future may error or produce different behavior
#   annotation = ("{:" + self.fmt + "}").format(val)

# %% [markdown]
# ### 직접 실험해 보세요! 몇 달을 살펴보고 일년 내내 다른 관계가 있는지 알아보세요!

# %%
snsplot = sns.heatmap(data_apr.corr(), annot=True,linewidths=0.5, fmt='.1f')
#snsplot.figure.savefig("corr_data.png")

plt.show()
# Out:
# C:\Users\gadi2\AppData\Local\Temp\ipykernel_13600\1930618284.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   snsplot = sns.heatmap(data_apr.corr(), annot=True,linewidths=0.5, fmt='.1f')
# c:\Users\gadi2\anaconda3\Lib\site-packages\seaborn\matrix.py:260: FutureWarning: Format strings passed to MaskedConstant are ignored, but in future may error or produce different behavior
#   annotation = ("{:" + self.fmt + "}").format(val)

# %% [markdown]
# ### 관계의 산점도 그리기

# %%
temperature_sep = data_sep['Temperature (C)']
humidity_sep = data_sep['Humidity']

plt.figure(figsize=(5,5))
ax2 = sns.scatterplot(x=temperature_sep, y=humidity_sep)
plt.show()

# %% [markdown]
# 위 그래프를 살펴보면 두 변수의 관계는 이전에 비해 더 선형적인 경향을 보여줍니다. 아마도 몇 달 안에 온도를 기반으로 습도를 더 잘 예측할 수 있는 모델을 만들 수 있을 것입니다. Sklearn 라이브러리를 사용하여 이 작업을 수행하는 방법을 알아보겠습니다.

# %% [markdown]
# ### scikit learn 라이브러리를 사용한 회귀 분석
#
# 기계 학습을 통해 우리는 선택한 특성과 대상 변수 사이의 관계를 설명할 수 있는 가장 적합한 선을 결정할 것입니다.
#
# 데이터를 예측하기 전에 sklearn 라이브러리에서 가져와야 하는 몇 가지 사항이 있습니다.

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %% [markdown]
# 다음으로 회귀 모델의 특성과 대상을 설정합니다.

# %%
features_available = [
    'Temperature (C)', 
]
X = data[features_available]
y = data['Humidity']

print('x type :', type(X))
print('y type :', type(y))
# Out:
# x type : <class 'pandas.core.frame.DataFrame'>
# y type : <class 'pandas.core.series.Series'>

# %% [markdown]
# ### 활동 8:
# 위의 코드에서 무엇이 종속 변수이고 독립 변수입니까?

# %% [markdown]
# 답변 : X는 독립변수들의 특징(feature)을 담고 있고, y는 종속변수를 담고 있습니다.
# 따라서 주어진 코드에서는 온도(Temperature (C))가 독립변수이고, 습도(Humidity)가 종속변수입니다.

# %% [markdown]
# ### 데이터를 훈련 세트와 테스트 세트로 나누기

# %% [markdown]
# 이제 테스트 세트와 훈련 세트로 데이터를 나눕니다. 데이터를 훈련 세트와 테스트 세트로 분할하는 이유는 무엇입니까?
#
# 지도 학습 문제에서 학습 기능을 위해 훈련 데이터 세트(선택한 특성과 대상으로 구성)를 제공해야 합니다. 그런 다음 훈련 세트를 기반으로 모델을 생성합니다.
#
# 테스트 세트는 모델의 성능을 확인하기 위해 모델의 예측 값을 테스트하는 데 사용됩니다.
#
# 자세한 내용은 https://towardsdatascience.com/train-test-split-and-cross-validation-in-python-80b61beca4b6 을 참조하세요.
#
# 테스트 및 훈련 세트를 분할하는 이유와 모델을 과대적합하거나 과소적합한 경우 그 효과에 대한 자세한 정보를 얻으려면 '모델에 대한 과대적합/과소적합이란?' 노트북 섹션을 참조하십시오.
#
# train_test_split 함수를 호출하여 코드를 구현해 보겠습니다. 훈련 세트를 데이터의 70%로, 테스트 세트를 데이터의 30%로 분할할 것입니다.

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3)

# %% [markdown]
# 이제 훈련 및 테스트 데이터 세트를 얻었습니다. 이러한 변수의 모양을 출력하여 테스트 세트가 총 데이터의 0.3이고 훈련 세트가 총 데이터의 0.7인지 확인하는 코드를 작성해 보세요.

# %%
# 훈련 세트와 테스트 세트의 크기 확인
train_set_size = len(X_train)
test_set_size = len(X_test)
total_size = len(X)

# 각 세트의 크기 출력
print("훈련 세트 크기:", train_set_size)
print("테스트 세트 크기:", test_set_size)
print("전체 데이터셋 크기:", total_size)

# 비율 확인
print("테스트 세트 비율:", test_set_size / total_size)
print("훈련 세트 비율:", train_set_size / total_size)
# Out:
# 훈련 세트 크기: 64637
# 테스트 세트 크기: 27702
# 전체 데이터셋 크기: 92339
# 테스트 세트 비율: 0.30000324889808205
# 훈련 세트 비율: 0.699996751101918

# %% [markdown]
# ### 선형 회귀 객체 생성
# 우리는 이전에 scikit learn에서 Linear Regression 클래스를 가져왔습니다. 이제 이 클래스를 이용하여 아래 코드와 같이 선형 회귀 개체를 만들 수 있습니다.

# %%
linreg = LinearRegression()

# %% [markdown]
# Python에서 객체는 특정 특성(변수)과 메소드(함수)를 포함합니다.
#
# 이제 'fit'이라는 함수를 이용하여 데이터 세트를 설명하는 가장 좋은 선을 찾습니다.
# 훈련 데이터 세트를 사용한 모델 훈련입니다.
#
# 이제 드디어 선형 회귀 함수를 사용하는 부분에 도달했습니다.
# 다음은 훈련 세트를 사용하여 데이터를 피팅하고 테스트 세트를 사용하여 예측하는 단계입니다.
# 그런 다음 mean_absolute_error를 사용하여 모델의 효율성을 테스트하여 테스트와 예측 값이 얼마나 차이가 있는지 확인합니다.

# %%
linreg.fit(X_train,y_train) # 선형 회귀 모델 훈련
# Out:
# LinearRegression()

# %% [markdown]
# 훈련 후에 우리는 선의 절편과 기울기를 출력할 수 있습니다.

# %%
#절편을 출력합니다:
print(linreg.intercept_)
#기울기를 출력합니다:
print(linreg.coef_)
# Out:
# 0.8910511864379624
# [-0.01312018]

# %% [markdown]
# 이제 모델을 학습했으므로 몇 가지 예측을 할 수 있습니다.

# %%
y_pred = linreg.predict(X_test)

# %% [markdown]
# 이제 습도의 실제 값과 예측 값을 비교하는 데이터 프레임을 만들 수 있습니다.

# %%
df = pd.DataFrame(columns=['Actual', 'Predicted'])

# %%
df['Actual'] = y_test
df['Predicted'] = y_pred

# %%
df
# Out:
#        Actual  Predicted
# 34948    0.73   0.614070
# 53611    0.46   0.497154
# 39985    1.00   0.737691
# 39270    0.85   0.659261
# 6366     0.81   0.744907
# ...       ...        ...
# 55410    0.76   1.073276
# 42786    0.77   0.723696
# 37927    0.92   0.940762
# 68118    0.87   0.796440
# 79918    0.90   0.644173
#
# [27702 rows x 2 columns]

# %% [markdown]
# 다음으로 그래프를 그려 최적의 선으로 데이터 세트를 표시합니다.

# %%
plt.scatter(X_test, y_test,  color='gray')
plt.plot(X_test, y_pred, color='red', linewidth=2)
plt.show()

# %% [markdown]
# 선이 데이터의 일반적인 추세를 따르는 것을 볼 수 있습니다. 그러나 산점도에서 볼 수 있듯이 데이터 자체 내에는 큰 변동이 있습니다. 즉, 선이 데이터를 정확하게 예측할 수 없습니다.
#
# 이제 데이터를 일치시키고 예측하는 라인의 능력을 측정하는 데 사용할 수 있는 몇 가지 측정 지표에 대해 알아보겠습니다.

# %% [markdown]
# ### 모델 평가
# 최적의 라인을 평가하기 위한 다양한 방법이 있습니다. 선형 회귀 문제에 대해 사용하는 일반적인 세 가지 측정 지표에 대하여 이 [링크](https://medium.com/acing-ai/how-to-evaluate-regression-models-d183b4f5853d)를 참조하십시오.

# %%
print ("Linear Regression Score")
predict = linreg.predict(X_test)
print ("Mean Absolute Error: ", mean_absolute_error(y_test,y_pred))
print ("Mean Squared Error: ", mean_squared_error(y_test,y_pred))
print ("R2: ", r2_score(y_test,y_pred))
# Out:
# Linear Regression Score
# Mean Absolute Error:  0.1210712662797464
# Mean Squared Error:  0.02237406147308536
# R2:  0.4165253608052678

# %% [markdown]
# 초기 데이터 세트가 특정 경향이나 관계를 가지지 않았기 때문에 모델의 성능이 다소 떨어집니다.
#
# 이제 월간 데이터를 사용하여 습도와 온도라는 두 변수 사이의 관계를 표시해 보겠습니다.

# %% [markdown]
# ## 이제 9월 데이터를 사용해 보세요.
#
# 이제 9월 데이터를 사용하여 선형 회귀 모델을 훈련합니다.

# %% [markdown]
# ### 특성을 선택합니다.

# %%
features_available = [
    'Temperature (C)', 
]
X2 = data_sep[features_available]
y2 = data_sep['Humidity']

# %% [markdown]
# ### 데이터를 분할합니다.

# %%
X2_train, X2_test, y2_train, y2_test = train_test_split(X2,y2,test_size=0.3)

# %% [markdown]
# ### 선형 회귀 인스턴스(instance)를 생성합니다.

# %%
linreg = LinearRegression()

# %% [markdown]
# ### 모델을 학습시킵니다.

# %%
linreg.fit(X2_train,y2_train) # 선형 회귀 모델 훈련
# Out:
# LinearRegression()

# %% [markdown]
# ### 절편과 기울기를 출력합니다.

# %%
#절편을 출력합니다:
print(linreg.intercept_)
#기울기를 출력합니다:
print(linreg.coef_)
# Out:
# 1.1696306873082578
# [-0.02749897]

# %% [markdown]
# ### 테스트 데이터를 사용하여 예측합니다.

# %%
y2_pred = linreg.predict(X2_test)
df2 = pd.DataFrame(columns=['Actual', 'Predicted'])

# %% [markdown]
# ### 데이터 프레임을 사용하여 실제 값과 예측 값 비교합니다.

# %%
df2['Actual'] = y2_test
df2['Predicted'] = y2_pred
df2
# Out:
#        Actual  Predicted
# 69656    0.80   0.904724
# 43254    1.00   0.758368
# 96065    0.84   0.912515
# 96216    0.96   0.987526
# 43814    0.69   0.518516
# ...       ...        ...
# 60977    0.85   0.857670
# 34697    0.33   0.483531
# 34940    0.67   0.751494
# 52216    0.50   0.482615
# 34436    0.59   0.615374
#
# [2265 rows x 2 columns]

# %% [markdown]
# ### 그래프를 그립니다.

# %%
plt.scatter(X2_test, y2_test,  color='lightgreen')
plt.plot(X2_test, y2_pred, color='black', linewidth=2)
plt.show()

# %% [markdown]
# 현재 최적의 선이 데이터 세트에 더 가깝기 때문에 선을 이용하여 온도 기반 습도 값을 더 잘 예측할 수 있을 것 같습니다.

# %% [markdown]
# ### 성능 지표를 출력하세요.

# %%
print ("Linear Regression Score2")
predict2 = linreg.predict(X2_test)
print ("Mean Absolute Erro2r: ", mean_absolute_error(y2_test,y2_pred))
print ("Mean Squared Error2: ", mean_squared_error(y2_test,y2_pred))
print ("R2: ", r2_score(y2_test,y2_pred))
# Out:
# Linear Regression Score2
# Mean Absolute Erro2r:  0.10459162535100575
# Mean Squared Error2:  0.016423553686682867
# R2:  0.6225771521906271

# %% [markdown]
# 성능이 더 좋아졌습니다!

# %% [markdown]
# ### 결론
#
# 우리는 기계 학습이 분류 및 회귀 모델 모두에 사용될 수 있다는 것을 배웠습니다.
# 노트북에서는 선형 회귀 모델만 다루었지만 데이터를 더 잘 나타낼 수 있는 다른 회귀 모델이 많이 있습니다. 복잡한 관계가 있는 경우 신경망을 사용하여 데이터 세트를 더 잘 설명할 수 있는 모델을 만들 수도 있습니다.

# %% [markdown]
# ## 챌린지 타임
# 이 글을 읽고 선형 회귀 대신 다항식 회귀를 사용하여 모델을 구현해 보십시오. https://medium.com/towards-data-science/polynomial-regression-bbe8b9d97491

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# CSV 파일 읽기
data = pd.read_csv("./[Dataset] Module 18 (weatherHistory).csv")

# 날짜 열을 날짜와 시간으로 변환
data['Formatted Date'] = pd.to_datetime(data['Formatted Date'], format='%Y-%m-%d %H:%M:%S.%f', utc=True)

# 월 별 데이터로 분리
data['month'] = data['Formatted Date'].dt.month

data_jan = data[data.month == 1]
data_feb = data[data.month == 2]
data_mar = data[data.month == 3]
data_apr = data[data.month == 4]
data_may = data[data.month == 5]
data_jun = data[data.month == 6]
data_jul = data[data.month == 7]
data_aug = data[data.month == 8]
data_sep = data[data.month == 9]
data_oct = data[data.month == 10]
data_nov = data[data.month == 11]
data_dec = data[data.month == 12]

# 필요한 열만 선택하여 특성과 타겟 데이터로 분할
X = data_sep[['Temperature (C)']].values
y = data_sep['Humidity'].values

# 데이터를 트레이닝(train) 세트와 테스트(test) 세트로 나눔
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# 다항식 특성 추가
degree = 2  # 다항식의 차수
poly_features = PolynomialFeatures(degree=degree)
X_train_poly = poly_features.fit_transform(X_train)
X_test_poly = poly_features.transform(X_test)

# 선형 회귀 모델 생성 및 학습
model = LinearRegression()
model.fit(X_train_poly, y_train)

# 테스트 데이터로 예측
y_test_pred = model.predict(X_test_poly)

# 테스트 데이터 산점도와 예측 결과 시각화 # scatter에서 s는 점의 크기
plt.figure(figsize=(5, 8))
plt.scatter(X_test, y_test, color='gray', label='Test data' , s=10)
plt.plot(X_test, y_test_pred, color='red', label='Predicted (Test)', linewidth=2)
plt.title('Polynomial Regression - Test data')
plt.xlabel('Temperature (C)')
plt.ylabel('Humidity')
plt.legend()
plt.grid(True)
plt.show()

# %%
print(type(X_test))
# Out:
# <class 'numpy.ndarray'>

# %%
sorted_zip3 = sorted(zip(X_test, y_test_pred), key=lambda x: x[0])
x, y = zip(*sorted_zip3)

plt.scatter(X_test, y_test, color='gray', label='Test data', s=10)
plt.plot(x, y, color='red', linewidth=2)

plt.title('Polynomial Regression - Test data')
plt.xlabel('Temperature (C)')
plt.ylabel('Humidity')
plt.legend()
plt.grid(True)
plt.show()
